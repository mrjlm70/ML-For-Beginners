# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model, model_selection

# %%
X, y = datasets.load_diabetes(return_X_y=True)
print(X.shape)
print(X[0])
# Out:
# (442, 10)
# [ 0.03807591  0.05068012  0.06169621  0.02187239 -0.0442235  -0.03482076
#  -0.04340085 -0.00259226  0.01990749 -0.01764613]

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.33)
X_train = X_train[:, 0].reshape(-1, 1)
X_test = X_test[:, 0].reshape(-1, 1)
print(X_test.shape)
# Out:
# (146, 1)

# %%
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
plt.scatter(X_test[:, 0], y_test,  color='black')
plt.plot(X_test[:, 0], y_pred, color='blue', linewidth=3)
plt.xlabel('Scaled BMIs')
plt.ylabel('Disease Progression')
plt.title('A Graph Plot Showing Diabetes Progression Against BMI')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# اطمینان از اینکه X_test و y_test به شکل صحیح تبدیل می‌شن
x_vals = np.ravel(X_test[:, 0])  # فقط اولین ویژگی، و تخت‌شده
y_vals = np.ravel(y_test)        # خروجی هم تخت بشه
print(x_vals.shape)
print(y_vals.shape)

# رسم نمودار
plt.scatter(x_vals, y_vals, color='black')

# اگر y_pred هم وجود داره:
y_pred_vals = np.ravel(y_pred)
plt.plot(x_vals, y_pred_vals, color='blue', linewidth=2)

plt.xlabel('Feature 0 (e.g., BMI)')
plt.ylabel('Target')
plt.title('Regression Plot')
plt.grid(True)
plt.show()
# Out:
# (146,)
# (146,)
